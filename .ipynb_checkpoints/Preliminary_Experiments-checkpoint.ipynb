# %% [markdown]
# # Experiments from Welling et al. paper.
#
# "Bayesian Learning via Stochastic Gradient Langevin Dynamics"
# ---
# ** Simple Demonstration **
#
# $\theta_1 \sim N(0,\sigma_{1}^2)$ ; $\theta_2 \sim N(0,\sigma_{2}^2)$ <br>
# $x_i \sim \frac{1}{2}N(\theta_1,\sigma_{x}^2) + \frac{1}{2}N(\theta_1 + \theta_2,\sigma_{x}^2)$

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Some parameters
data_size = 10000
var1 = 10; var2 = 1; varx = 2

theta1=np.random.normal(0,np.sqrt(var1),data_size)
theta2=np.random.normal(0,np.sqrt(var2),data_size)
Theta1, Theta2 = np.meshgrid(theta1,theta2)

x = 0.5*np.random.normal(theta1,np.sqrt(varx),data_size) + 0.5*np.random.normal(theta1+theta2,np.sqrt(varx),data_size)

# %%
print(x)
# Out:
# [ 1.13151632  2.62203426  0.35657047 ...  2.6648477   2.04729542
#  -0.36793851]

# %%
histogram,bins = np.histogram(x,bins=50,range=[-7,7], density=False)
midx = (bins[0:-1]+bins[1:])/2

plt.plot(midx,histogram)

plt.title('Distribution of $x$')
plt.xlabel('$x$')
plt.xlabel('Density')
plt.show()
# plt.scatter(theta1,theta2)
# plt.show()

# %%
print(np.mean(x))
# Out:
# 0.5003366140355409

# %%
import scipy.stats as stat


data_size = 100

var1 = 10; var2 = 1; varx = 2
x=np.random.normal(0,np.sqrt(var1),data_size)
y=np.random.normal(1,np.sqrt(var2),data_size)
X, Y = np.meshgrid(np.sort(theta1),np.sort(theta2))

# x = np.arange(-2.0, 2.0, 0.1)
# y = np.arange(-3.0, 3.0, 0.1)
# X, Y = np.meshgrid(x, y)

Z = 0.5*stat.norm(0,np.sqrt(varx)).pdf(X) + 0.5*stat.norm(1,np.sqrt(varx)).pdf(Y)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-114-ca010727b869> in <module>()
#      13 # X, Y = np.meshgrid(x, y)
#      14
# ---> 15 Z = 0.5*stat.norm(0,np.sqrt(varx)).pdf(X) + 0.5*stat.norm(1,np.sqrt(varx)).pdf(Y)
#
# ~\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py in pdf(self, x)
#     448
#     449     def pdf(self, x):   # raises AttributeError in frozen discrete distribution
# --> 450         return self.dist.pdf(x, *self.args, **self.kwds)
#     451
#     452     def logpdf(self, x):
#
# ~\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py in pdf(self, x, *args, **kwds)
#    1650         args = tuple(map(asarray, args))
#    1651         dtyp = np.find_common_type([x.dtype, np.float64], [])
# -> 1652         x = np.asarray((x - loc)/scale, dtype=dtyp)
#    1653         cond0 = self._argcheck(*args) & (scale > 0)
#    1654         cond1 = self._support_mask(x) & (scale > 0)
#
# MemoryError:

# %%
plt.contour(X,Y,Z)
plt.show()

# %%
data_size = 100

var1 = 10; var2 = 1; varx = 2
# x=np.random.normal(0,np.sqrt(var1),data_size)
# y=np.random.normal(0,np.sqrt(var2),data_size)
# X, Y = np.meshgrid(np.sort(theta1),np.sort(theta2))

x = np.arange(-2.0, 2.0, 0.1)
y = np.arange(-3.0, 3.0, 0.1)
X, Y = np.meshgrid(x, y)

pos = np.empty(X.shape + (2,))
pos[:, :, 0] = X; pos[:, :, 1] = Y

Z = 0.5*stat.multivariate_normal([0, 1],[[np.sqrt(varx*varx),0],[0, np.sqrt(varx*varx)]]).pdf(pos)

# %%
plt.contour(X,Y,Z)
plt.show()

# %% [markdown]
# #### Implementation of Stochatic Gradient Descent
# I am applying the stochastic gradient descent based on this article:
# https://www.pyimagesearch.com/2016/10/17/stochastic-gradient-descent-sgd-with-python/

# %%
def sigmoid_activation(x):
    '''compute and return the sigmoid activation value for a
    given input value'''
    return 1.0 / (1 + np.exp(-x))
 
def next_batch(X, y, batchSize):
    '''loop over our dataset `X` in mini-batches of size `batchSize`
    with labels (classification) y'''
    for i in np.arange(0, X.shape[0], batchSize):
        # yield a tuple of the current batched data and labels
        yield (X[i:i + batchSize], y[i:i + batchSize])

# %%
# loop over the desired number of epochs
for epoch in np.arange(0, args["epochs"]):
	# initialize the total loss for the epoch
	epochLoss = []
 
	# loop over our data in batches
	for (batchX, batchY) in next_batch(X, y, args["batch_size"]):
		# take the dot product between our current batch of
		# features and weight matrix `W`, then pass this value
		# through the sigmoid activation function
		preds = sigmoid_activation(batchX.dot(W))
 
		# now that we have our predictions, we need to determine
		# our `error`, which is the difference between our predictions
		# and the true values
		error = preds - batchY
 
		# given our `error`, we can compute the total loss value on
		# the batch as the sum of squared loss
		loss = np.sum(error ** 2)
		epochLoss.append(loss)
 
		# the gradient update is therefore the dot product between
		# the transpose of our current batch and the error on the
		# # batch
		gradient = batchX.T.dot(error) / batchX.shape[0]
 
		# use the gradient computed on the current batch to take
		# a "step" in the correct direction
		W += -args["alpha"] * gradient
 
	# update our loss history list by taking the average loss
	# across all batches
	lossHistory.append(np.average(epochLoss))
