# %%
import numpy as np
from functools import partial
import matplotlib.pyplot as plt 
import time

# %%
Y=np.load('tomatoes.npy') # Make sure you downloaded this file from Learn!
print('Length of data: ' + str(len(Y)))
print('Data:')
print(Y)
# Out:
# Length of data: 30
# Data:
# [13.27597167 15.08565281 13.41061844 11.5510474  10.63232069 13.76932811
#  10.31644803 14.55388057 12.57937117 14.13647951 15.37354413  9.96525246
#  12.66541964 11.33164599 12.14113179 11.57753389 15.86128067 10.23999543
#  16.36971379 13.96021609 17.27321719 12.23476479 17.96792692 13.92888826
#  10.64602864 16.45922776 15.56009798 13.02118014 16.50556431 14.08484862]

# %%
def U(q,y):
    m1,m2,m3 = q 
    
    n = len(y)
    p_prior = np.exp(-(13.5-m1)**2/32)*np.exp(-(13.5 - m2)**2/32)*np.exp(-(13.5 - m3)**2/32)
    log_prior = np.log(p_prior)
    m1_vec = m1*np.ones(n)
    m2_vec = m2*np.ones(n)
    m3_vec = m3*np.ones(n)
    p_hat = np.exp(-(y-m1_vec)**2/2) + np.exp(-(y-m2_vec)**2/2) + np.exp(-(y-m3_vec)**2/2)
    log_p_hat = np.log(p_hat)
    V = -log_prior - sum(log_p_hat)
    
    return V

# %%
def run_simulation_with_data( q0,p0, Nsteps, h, gamma, step_function, force_function, Y):
    
    q_traj = [np.copy(q0)] 
    p_traj = [np.copy(p0)]
    t_traj = [0]

    q = np.copy(q0) 
    p = np.copy(p0)
    t = 0 

    for n in range(Nsteps):
        q,p = step_function(q, h, Y)
        t = t + h 

        q_traj += [q] 
        p_traj += [p]   
        t_traj += [t] 

    q_traj = np.array(q_traj) 
    p_traj = np.array(p_traj) 
    t_traj = np.array(t_traj) 

    return q_traj, p_traj, t_traj

# %%
def force(q,y):
    m1,m2,m3 = q  
    
    n = len(y)
    p_prior = np.exp(-(13.5 - m1)**2/32)*np.exp(-(13.5 - m2)**2/32)*np.exp(-(13.5 - m3)**2/32)
    
    m1_vec = m1*np.ones(n)
    m2_vec = m2*np.ones(n)
    m3_vec = m3*np.ones(n)
    p_hat = np.exp(-(y-m1_vec)**2/2) + np.exp(-(y-m2_vec)**2/2) + np.exp(-(y-m3_vec)**2/2)
    
    # Take the negative of each gradient
    grad_m1 = -(-(1/16)*(13.5 - m1) + sum(-(y - m1_vec)*np.exp(-(y - m1_vec)**2/2)/p_hat))
    grad_m2 = -(-(1/16)*(13.5 - m2) + sum(-(y - m2_vec)*np.exp(-(y - m2_vec)**2/2)/p_hat))
    grad_m3 = -(-(1/16)*(13.5 - m3) + sum(-(y - m3_vec)*np.exp(-(y - m3_vec)**2/2)/p_hat))
    
    return grad_m1,grad_m2,grad_m3

# %%
# Out:
# (-11.386420021143474, -4.188324781955538, 12.360380829908367)

# %%
def HMC_with_data(q0,h,y):
    q = q0
    p = np.random.randn(3)
    current_p = p
    
    p = p + h*np.asarray(force(q,y))/2
    q = q + h*p
    p = p + h*np.asarray(force(q,y))/2
    p = -p
    
    current_U = U(q0,y)
    current_K = sum(current_p**2)/2
    proposed_U = U(q, y)
    proposed_K = sum(p**2)/2
    
    accept = -1
    if np.random.uniform(0,1) < np.exp(current_U - proposed_U + current_K - proposed_K):
        accept = 1
        return q, accept      # accept
    else:
        accept = 0
        return q0, accept     # reject

# %%
q0 = np.random.randn(3) + 13   # initialise q0 to be close to the mean (of tomato mass)
p0 = np.random.randn(3)

.2*np.asarray(force(q0,Y))/2
# Out:
# array([-0.22989562,  2.08067981, -0.47117754])

# %%
Nsteps = 100000
h = 0.2
gamma = 1.0
tic = time.clock()

# Run one long trajectory of Nsteps, using the ABO scheme
q_traj, p_traj, t_traj = run_simulation_with_data(q0, p0, Nsteps , h, gamma, HMC_with_data, force, Y)


toc = time.clock()
print(toc - tic)
# Out:
# 36.054905999999995

# %%
fig = plt.figure(figsize=[15,4])

plt.subplot(1,2,1)
plt.plot( t_traj, q_traj )
plt.title('Trajectory of $q$')
plt.ylabel('$q(t)$')
plt.xlabel('Time $t$')

plt.subplot(1,2,2)
hist1,bins1 = np.histogram(q_traj[:,0], bins=50,range=[9,18], density=True)
midx1 = (bins1[0:-1]+bins1[1:])/2
hist2,bins2 = np.histogram(q_traj[:,1], bins=50,range=[9,18], density=True)
midx2 = (bins2[0:-1]+bins2[1:])/2
hist3,bins3 = np.histogram(q_traj[:,2], bins=50,range=[9,18], density=True)
midx3 = (bins3[0:-1]+bins3[1:])/2
plt.plot(midx1,hist1,label='\mu_A')
plt.plot(midx2,hist2,label='\mu_A')
plt.plot(midx3,hist3,label='\mu_A')

plt.title('Histograms of distributions of $q = [\mu_A, \mu_B, \mu_C]$')
plt.xlabel('Mass (g)')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
hist1,bins1 = np.histogram(q_traj[:,0], bins=40,range=[9,18], density=True)
midx1 = (bins1[0:-1]+bins1[1:])/2
hist2,bins2 = np.histogram(q_traj[:,1], bins=40,range=[9,18], density=True)
midx2 = (bins2[0:-1]+bins2[1:])/2
hist3,bins3 = np.histogram(q_traj[:,2], bins=40,range=[9,18], density=True)
midx3 = (bins3[0:-1]+bins3[1:])/2
plt.plot(midx1,hist1,label='\mu_A')
plt.plot(midx2,hist2,label='\mu_A')
plt.plot(midx3,hist3,label='\mu_A')

plt.title('Histograms of distributions of $q = [\mu_A, \mu_B, \mu_C]$')
plt.xlabel('Mass (g)')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
n = q_traj.shape[0]  # get number of time steps
q_traj_sorted = q_traj.copy()

for k in range(n):
    q_traj_sorted[k] = np.sort(q_traj[k])
    
hist1,bins1 = np.histogram(q_traj_sorted[:,0], bins=40,range=[9,18], density=True)
midx1 = (bins1[0:-1]+bins1[1:])/2
hist2,bins2 = np.histogram(q_traj_sorted[:,1], bins=40,range=[9,18], density=True)
midx2 = (bins2[0:-1]+bins2[1:])/2
hist3,bins3 = np.histogram(q_traj_sorted[:,2], bins=40,range=[9,18], density=True)
midx3 = (bins3[0:-1]+bins3[1:])/2
plt.plot(midx1,hist1,label='$\mu_A$')
plt.plot(midx2,hist2,label='$\mu_A$')
plt.plot(midx3,hist3,label='$\mu_A$')

plt.title('Histograms of distributions of $q = [\mu_A, \mu_B, \mu_C]$ after sorted')
plt.xlabel('Mass (g)')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
print(np.var(q_traj_sorted[:,0]))
print(np.var(q_traj_sorted[:,1]))
print(np.var(q_traj_sorted[:,2]))
# Out:
# 0.1775169666686814
# 0.2548372140869495
# 0.19874475259245053

# %% [markdown]
# We shall use a Gaussian prior with a large variance, just to keep us from sampling e.g. negative numbers. We will put the centre of the prior at 13.5, which is roughly the middle of the data.
#
# $$ \rho_\text{prior}(\mu_A,\mu_B,\mu_C) \propto \exp({-(13.5-\mu_A)^2/32}) \exp({-(13.5-\mu_B)^2/32}) \exp({-(13.5-\mu_B)^2/32}) $$

# %%
# Minibatch size: n

def get_minibatch(y,n):
    # x must be an array
    np.random.shuffle(y)
    batch = y[0:n-1]
    y = y[n:]
    return batch, y
    

def force_noise(q,y_batch,batch_scaling):
    n = len(y_batch)
    m1,m2,m3 = q  
    p_prior = np.exp(-(13.5 - m1)**2/32)*np.exp(-(13.5 - m2)**2/32)*np.exp(-(13.5 - m3)**2/32)
    
    m1_vec = m1*np.ones(n)
    m2_vec = m2*np.ones(n)
    m3_vec = m3*np.ones(n)
    p_hat = np.exp(-(y_batch-m1_vec)**2/2) + np.exp(-(y_batch-m2_vec)**2/2) + np.exp(-(y_batch-m3_vec)**2/2)
    
    
    # Take the negative of each gradient
    grad_m1 = -(-(1/16)*(13.5 - m1) + batch_scaling*sum(-(y_batch - m1_vec)*np.exp(-(y_batch - m1_vec)**2/2)/p_hat))  
    grad_m2 = -(-(1/16)*(13.5 - m2) + batch_scaling*sum(-(y_batch - m2_vec)*np.exp(-(y_batch - m2_vec)**2/2)/p_hat))
    grad_m3 = -(-(1/16)*(13.5 - m3) + batch_scaling*sum(-(y_batch - m3_vec)*np.exp(-(y_batch - m3_vec)**2/2)/p_hat))
    
    return grad_m1,grad_m2,grad_m3


def HMC_with_noise(q0,h,y,n):
    # n is the size of the batch
    batch_scaling = len(y)/n
    q = q0
    p = np.random.randn(3)
    current_p = p
    
    y_batch, y_updated = get_minibatch(y,n)
    
    p = p + h*np.asarray(force_noise(q,y_batch,batch_scaling))/2
    q = q + h*p
    p = p + h*np.asarray(force_noise(q,y_batch,batch_scaling))/2
    p = -p
    
    current_U = U(q0,y)
    current_K = sum(current_p**2)/2
    proposed_U = U(q, y)
    proposed_K = sum(p**2)/2
    
    accept = -1
    if np.random.uniform(0,1) < np.exp(current_U - proposed_U + current_K - proposed_K):
        accept = 1
        return q, accept,y_updated      # accept
    else:
        accept = 0
        return q0, accept, y_updated     # reject

# %%
y_batch, y = get_minibatch(Y,5)
y_batch
grad1,grad2,grad3 = force_noise(q0,y_batch,1/5)
grad1,grad2,grad3
# Out:
# (0.2182508673597685, -0.04541477024192366, 0.003793605821755034)

# %%
def run_simulation_with_noise( q0,p0, Nsteps, h, step_function, Y, batch_size):
    
    num_scans = len(Y)/batch_size
    q_traj = [np.copy(q0)] 
    p_traj = [np.copy(p0)]
    t_traj = [0]

    q = np.copy(q0) 
    p = np.copy(p0)
    t = 0 
    y_updated = Y
    scans = num_scans
    for n in range(Nsteps):
        if scans == 0:
            scans = num_scans
            y_updated = Y
        q,p,y_updated = step_function(q, h, y_updated, batch_size)
        t = t + h 

        q_traj += [q] 
        p_traj += [p]   
        t_traj += [t]
        scans = scans - 1

    q_traj = np.array(q_traj) 
    p_traj = np.array(p_traj) 
    t_traj = np.array(t_traj) 

    return q_traj, p_traj, t_traj

# %%
Nsteps = 100000
h = 0.2

tic = time.clock()
# Run one long trajectory of Nsteps, using the ABO scheme
q_traj_noise, p_traj, t_traj = run_simulation_with_noise(q0, p0, Nsteps , h, HMC_with_noise, Y, 3)
toc = time.clock()
print(toc - tic)
# Out:
# 33.23852299999999

# %%
fig = plt.figure(figsize=[15,10])
plt.rcParams.update({'font.size': 25})


hist1,bins1 = np.histogram(q_traj_noise[:,0], bins=40,range=[9,18], density=True)
midx1 = (bins1[0:-1]+bins1[1:])/2
hist2,bins2 = np.histogram(q_traj_noise[:,1], bins=40,range=[9,18], density=True)
midx2 = (bins2[0:-1]+bins2[1:])/2
hist3,bins3 = np.histogram(q_traj_noise[:,2], bins=40,range=[9,18], density=True)
midx3 = (bins3[0:-1]+bins3[1:])/2
plt.plot(midx1,hist1,label='$\mu_A$')
plt.plot(midx2,hist2,label='$\mu_A$')
plt.plot(midx3,hist3,label='$\mu_A$')


plt.title('Histograms of distributions of $q = [\mu_A, \mu_B, \mu_C]$ using stochastic gradient')
plt.xlabel('Mass (g)')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
n = q_traj.shape[0]  # get number of time steps
q_traj_sorted = q_traj.copy()

# why did you do that? sorting in axis 0 or axis 1?
# why didn't you use the q_traj_noise
for k in range(n):
    q_traj_sorted[k] = np.sort(q_traj[k])

plt.figure(figsize=[15,10])
plt.hist(q_traj_sorted[:,0], bins=15,label='$\mu_A$', alpha=0.7)
plt.hist(q_traj_sorted[:,1], bins=15, label='$\mu_B$',alpha=0.7)
plt.hist(q_traj_sorted[:,2], bins=15, label='$\mu_C$',alpha=0.7)
plt.title('HMC (full gradient)')
plt.xlabel('Mass (g)')
plt.ylabel('Frequency')
plt.legend()
plt.show()
plt.figure()
hist1,bins1 = np.histogram(q_traj_sorted[:,0], bins=40,range=[9,18], density=True)
midx1 = (bins1[0:-1]+bins1[1:])/2
hist2,bins2 = np.histogram(q_traj_sorted[:,1], bins=40,range=[9,18], density=True)
midx2 = (bins2[0:-1]+bins2[1:])/2
hist3,bins3 = np.histogram(q_traj_sorted[:,2], bins=40,range=[9,18], density=True)
midx3 = (bins3[0:-1]+bins3[1:])/2
plt.plot(midx1,hist1,label='$\mu_A$')
plt.plot(midx2,hist2,label='$\mu_A$')
plt.plot(midx3,hist3,label='$\mu_A$')
plt.show()
print(np.var(q_traj_sorted[:,0]))
print(np.var(q_traj_sorted[:,1]))
print(np.var(q_traj_sorted[:,2]))
print('means')
print(np.mean(q_traj_sorted[:,0]))
print(np.mean(q_traj_sorted[:,1]))
print(np.mean(q_traj_sorted[:,2]))
    


n = q_traj.shape[0]  # get number of time steps
q_traj_sorted_noise = q_traj_noise.copy()

for k in range(n):
    q_traj_sorted_noise[k] = np.sort(q_traj_noise[k])

plt.figure(figsize=[15,10])
plt.hist(q_traj_sorted_noise[:,0], bins=15,label='$\mu_A$', alpha=0.7)
plt.hist(q_traj_sorted_noise[:,1], bins=15, label='$\mu_B$',alpha=0.7)
plt.hist(q_traj_sorted_noise[:,2], bins=15, label='$\mu_C$',alpha=0.7)
plt.title('HMC with stochastic gradient (mini-batch size of 3)')
plt.xlabel('Mass (g)')
plt.ylabel('Frequency')
plt.legend()
plt.show()


plt.figure()
hist1,bins1 = np.histogram(q_traj_sorted_noise[:,0], bins=40,range=[9,18], density=True)
midx1 = (bins1[0:-1]+bins1[1:])/2
hist2,bins2 = np.histogram(q_traj_sorted_noise[:,1], bins=40,range=[9,18], density=True)
midx2 = (bins2[0:-1]+bins2[1:])/2
hist3,bins3 = np.histogram(q_traj_sorted_noise[:,2], bins=40,range=[9,18], density=True)
midx3 = (bins3[0:-1]+bins3[1:])/2
plt.plot(midx1,hist1,label='$\mu_A$')
plt.plot(midx2,hist2,label='$\mu_A$')
plt.plot(midx3,hist3,label='$\mu_A$')
plt.show()

print(np.var(q_traj_sorted_noise[:,0]))
print(np.var(q_traj_sorted_noise[:,1]))
print(np.var(q_traj_sorted_noise[:,2]))
print('means')
print(np.mean(q_traj_sorted_noise[:,0]))
print(np.mean(q_traj_sorted_noise[:,1]))
print(np.mean(q_traj_sorted_noise[:,2]))
# Out:
# 0.1748607523436592
# 0.2577916779976359
# 0.19802744894248187
# means
# 11.205770967457505
# 13.571442029879698
# 16.124912762869457
# 0.4019965577574733
# 0.6401679717246438
# 0.5181992195263773
# means
# 11.251564650795757
# 13.572952186841958
# 16.06854860138701

# %%
batch, updated = get_minibatch_with_cov(Y, 2)
len(updated)

x = np.array([2,3,4,5,6])
print(x[0:2])
print(x[2:])
# Out:
# [2 3]
# [4 5 6]

# %%
batch,y_test = get_minibatch_with_cov(BigY,1000)
batch.shape
# Out:
# (500,)

# %%
# add in covariance term

def get_minibatch_with_cov(y,n):
    # x must be an array
    np.random.shuffle(y)
    batch = y[0:n]
    y = y[n:]
    return batch, y
    

# Minibatch size: n


def likelihood_grad(y_batch,q):
    m1,m2,m3 = q 
    batch_length = len(y_batch)
    m1_vec = m1*np.ones(batch_length)
    m2_vec = m2*np.ones(batch_length)
    m3_vec = m3*np.ones(batch_length)
    p_hat = np.exp(-(y_batch-m1_vec)**2/2) + np.exp(-(y_batch-m2_vec)**2/2) + np.exp(-(y_batch-m3_vec)**2/2)
#     if (np.mean(p_hat < .01)):
#         print(p_hat)
#         print('masses:', m1,m2,m3)
        
    grad1 = -(y_batch - m1_vec)*np.exp(-(y_batch - m1_vec)**2/2)/p_hat
    grad2 = -(y_batch - m2_vec)*np.exp(-(y_batch - m2_vec)**2/2)/p_hat
    grad3 = -(y_batch - m3_vec)*np.exp(-(y_batch - m3_vec)**2/2)/p_hat
        
    grad = np.array([grad1,grad2,grad3])
        
    return grad


def force_noise_with_cov(q,y_batch,batch_scaling):
    n = len(y_batch)
    m1,m2,m3 = q  
    p_prior = np.exp(-(13.5 - m1)**2/32)*np.exp(-(13.5 - m2)**2/32)*np.exp(-(13.5 - m3)**2/32)
    
    
    grad_prior = np.array([[-(1/16)*(13.5 - m1)], [-(1/16)*(13.5 - m2)], [-(1/16)*(13.5 - m3)]])
    
    
    # Take the negative of each gradient
    grad_m1 = -(grad_prior[0] + batch_scaling*sum(likelihood_grad(y_batch,q)[0]))  
    grad_m2 = -(grad_prior[1] + batch_scaling*sum(likelihood_grad(y_batch,q)[1]))
    grad_m3 = -(grad_prior[2] + batch_scaling*sum(likelihood_grad(y_batch,q)[2]))
    
    s_ti = np.zeros([3,n])
    for i in range(n):
        s = (1/n)*grad_prior + likelihood_grad([y_batch[i]],q)
        s_ti[:,i] = s[:,0]
         
    B_hat = batch_scaling**2 * np.cov(s_ti)   # covariance of the scores s_ti to estimate covariance matrix
    
    grad = np.array([grad_m1, grad_m2, grad_m3])
    
    return grad, B_hat

grad, B = force_noise_with_cov(q0,np.array([0,1,2]),2)
p = np.random.randn(3)
print('grad:', grad)
print('flatten grad:', np.matrix.flatten(grad))
print('B dot p', h*B.dot(p))

p = p + h*np.matrix.flatten(grad) - h*B.dot(p)
print(p)
# Out:
# grad: [[-6.47736006e-02]
#  [-9.92461391e-02]
#  [-6.93150064e+01]]
# flatten grad: [-6.47736006e-02 -9.92461391e-02 -6.93150064e+01]
# B dot p [ 8.43756065e-10  8.16329970e-03 -9.05907950e-01]
# [  0.26273215   0.45821444 -14.06587244]

# %%
def SGHMC(q0,h,y,N, batch_size):
    # n is the size of the batch
    batch_scaling = N/batch_size
    q = q0
    p = np.random.randn(3)
    current_p = p
    M = np.eye(3)   # preconditioning matrix set to identity. can be used to precondition sampler 
    # when we have more info about target distribution
    (y_batch, y_updated) = get_minibatch_with_cov(y,batch_size)
    grad, B_hat = force_noise_with_cov(q,y_batch, batch_scaling)
    print('B_hat',B_hat)
    # for now set C=B_hat and B=zeros(3)
    C = .5*h*B_hat
    B = np.zeros([3,3])
    #added_noise = np.random.multivariate_normal(np.zeros(3), 2*C*h, 1)
    
    
    p = p + h*np.matrix.flatten(grad) - h*C.dot(p) # + (2*h*C).dot(np.random.randn(3)) optional
    q = q + h*p
    
    
    return q, y_updated

# %%
B_hat = np.sqrt(np.ones([3,3]))
np.random.multivariate_normal(np.zeros(3),np.sqrt(2*B_hat*h),1).T
#grad

cov = np.array([[3,.1,.1],[.1,4,.1],[.1,.1,2]])
grad_noise = cov.dot(np.random.randn(3))

# %%
def run_simulation_sghmc( q0,p0, Nsteps, h, step_function, Y, batch_size):
    num_scans = len(Y)/batch_size - 1
    print('Num scans', num_scans)
    q_traj = [np.copy(q0)] 
    p_traj = [np.copy(p0)]
    t_traj = [0]

    q = np.copy(q0) 
    p = np.copy(p0)
    t = 0 
    y_updated = Y
    N = len(Y)
    scans = num_scans
    for n in range(Nsteps):
        if scans == 0:
            scans = num_scans
            y_updated = Y
        q,y_updated = step_function(q, h, y_updated, N, batch_size)
        t = t + h 

        q_traj += [q] 
        p_traj += [p]   
        t_traj += [t]
        scans = scans - 1

    q_traj = np.array(q_traj) 
    p_traj = np.array(p_traj) 
    t_traj = np.array(t_traj) 

    return q_traj, p_traj, t_traj

# %%
np.linalg.det(np.zeros([3,3]) - np.ones([3,3]))
# Out:
# 0.0

# %%
# RUN SGHMC (takes a while with covariance estimation)

Nsteps = 100000
h = 0.2

tic = time.clock()
# Run one long trajectory of Nsteps, using the ABO scheme
# B_hat [[ 8.21269370e+01 -5.84428484e-01 -2.30333510e+01]
#  [-5.84428484e-01  1.75710776e-02  5.40134883e-01]
#  [-2.30333510e+01  5.40134883e-01  1.70134675e+01]]
# B_hat [[  0.82621274   3.21829227  -4.29390681]
#  [  3.21829227  13.11205928 -17.10958361]
#  [ -4.29390681 -17.10958361  22.57156717]]
# B_hat [[  7.51244422  -4.06340548 -12.07422197]
#  [ -4.06340548  18.82406224   0.12011527]
#  [-12.07422197   0.12011527  21.8778784 ]]
# B_hat [[ 8.33229063 -6.3807361  -5.11118689]
#  [-6.3807361  37.22665441 12.71482187]
#  [-5.11118689 12.71482187  5.5302406 ]]
# B_hat [[ 2.22970274  1.32719759 -9.92448212]
#  [ 1.32719759  1.02280666 -5.91010535]
#  [-9.92448212 -5.91010535 44.1742362 ]]
# B_hat [[  0.46836758  -1.25247564   2.0482368 ]
#  [ -1.25247564  53.37768542 -23.39091032]
#  [  2.0482368  -23.39091032  15.37156561]]
# B_hat [[155.09205505 -15.64569567   9.71538222]
#  [-15.64569567   6.58161004  -7.6419275 ]
#  [  9.71538222  -7.6419275    9.47881434]]
# B_hat [[24.79694319  2.975703    8.28261435]
#  [ 2.975703    0.39670554  0.55400325]
#  [ 8.28261435  0.55400325  7.65237666]]
# B_hat [[  4.51715926  -6.75328788   8.97242363]
#  [ -6.75328788  13.52343801 -18.47272206]
#  [  8.97242363 -18.47272206  25.28899704]]
# B_hat [[ 0.06296585  0.06648235 -0.19279239]
#  [ 0.06648235  0.07035888 -0.20367353]
#  [-0.19279239 -0.20367353  0.59038216]]
# B_hat [[85.92176358  2.41993273 16.10707397]
#  [ 2.41993273 14.59260026 -4.336402  ]
#  [16.10707397 -4.336402    4.59918596]]
# B_hat [[ 88.29099082   5.64092837 -37.35924672]
#  [  5.64092837 119.01192521  33.58729382]
#  [-37.35924672  33.58729382  26.71518726]]
# B_hat [[ 52.96946435   7.21714289 -28.79448997]
#  [  7.21714289  25.94356485 -20.68508652]
#  [-28.79448997 -20.68508652  26.90908065]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-192-0d2855498545> in <module>()
#       6 tic = time.clock()
#       7 # Run one long trajectory of Nsteps, using the ABO scheme
# ----> 8 q_traj_sghmc, p_traj, t_traj = run_simulation_sghmc(q0, p0, Nsteps , h, SGHMC, Y, 3)
#       9 toc = time.clock()
#      10 print(toc - tic)
#
# <ipython-input-191-d84bfa6eba1f> in run_simulation_sghmc(q0, p0, Nsteps, h, step_function, Y, batch_size)
#      16             scans = num_scans
#      17             y_updated = Y
# ---> 18         q,y_updated = step_function(q, h, y_updated, N, batch_size)
#      19         t = t + h
#      20
#
# <ipython-input-188-86d1b2dac6d7> in SGHMC(q0, h, y, N, batch_size)
#      10     # when we have more info about target distribution
#      11     (y_batch, y_updated) = get_minibatch_with_cov(y,batch_size)
# ---> 12     grad, B_hat = force_noise_with_cov(q,y_batch, batch_scaling)
#      13     print('B_hat',B_hat)
#      14     # for now set C=B_hat and B=zeros(3)
#
# <ipython-input-181-c6b3de121419> in force_noise_with_cov(q, y_batch, batch_scaling)
#      48     s_ti = np.zeros([3,n])
#      49     for i in range(n):
# ---> 50         s = (1/n)*grad_prior + likelihood_grad([y_batch[i]],q)
#      51         s_ti[:,i] = s[:,0]
#      52
#
# <ipython-input-181-c6b3de121419> in likelihood_grad(y_batch, q)
#      15     m1,m2,m3 = q
#      16     batch_length = len(y_batch)
# ---> 17     m1_vec = m1*np.ones(batch_length)
#      18     m2_vec = m2*np.ones(batch_length)
#      19     m3_vec = m3*np.ones(batch_length)
#
# /anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py in ones(shape, dtype, order)
#     186
#     187     """
# --> 188     a = empty(shape, dtype, order)
#     189     multiarray.copyto(a, 1, casting='unsafe')
#     190     return a
#
# KeyboardInterrupt:

# %%
fig = plt.figure(figsize=[15,10])

plt.hist(q_traj_sghmc[:,0], bins=15,label='$\mu_A$', alpha=0.5)
plt.hist(q_traj_sghmc[:,1], bins=15, label='$\mu_B$',alpha=0.5)
plt.hist(q_traj_sghmc[:,2], bins=15, label='$\mu_C$',alpha=0.5)
plt.title('Histograms of distributions of $q = [\mu_A, \mu_B, \mu_C]$')
plt.xlabel('Mass (g)')
plt.ylabel('Frequency')
plt.legend()

fig = plt.figure()

hist1,bins1 = np.histogram(q_traj_sghmc[:,0], bins=50,range=[9,18], density=True)
midx1 = (bins1[0:-1]+bins1[1:])/2
hist2,bins2 = np.histogram(q_traj_sghmc[:,1], bins=50,range=[9,18], density=True)
midx2 = (bins2[0:-1]+bins2[1:])/2
hist3,bins3 = np.histogram(q_traj_sghmc[:,2], bins=50,range=[9,18], density=True)
midx3 = (bins3[0:-1]+bins3[1:])/2
plt.plot(midx1,hist1,label='$\mu_A$')
plt.plot(midx2,hist2,label='$\mu_B$')
plt.plot(midx3,hist3,label='$\mu_C$')

plt.title('Histograms of distributions of $q = [\mu_A, \mu_B, \mu_C]$')
plt.xlabel('Mass (g)')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
n = q_traj_sghmc.shape[0]  # get number of time steps
q_traj_sorted_sghmc = q_traj_sghmc.copy()

for k in range(n):
    q_traj_sorted_sghmc[k] = np.sort(q_traj_sghmc[k])

plt.figure(figsize=[15,10])
plt.hist(q_traj_sorted_sghmc[:,0], bins=15,label='$\mu_A$', alpha=0.7)
plt.hist(q_traj_sorted_sghmc[:,1], bins=15, label='$\mu_B$',alpha=0.7)
plt.hist(q_traj_sorted_sghmc[:,2], bins=15, label='$\mu_C$',alpha=0.7)
plt.title('SGHMC with mini-batch of size 3')
plt.xlabel('Mass (g)')
plt.ylabel('Frequency')
plt.legend()
plt.show()

print(np.var(q_traj_sorted_sghmc[:,0]))
print(np.var(q_traj_sorted_sghmc[:,1]))
print(np.var(q_traj_sorted_sghmc[:,2]))
print('original hmc')
print(np.var(q_traj_sorted[:,0]))
print(np.var(q_traj_sorted[:,1]))
print(np.var(q_traj_sorted[:,2]))
# Out:
# 0.23922672774802548
# 0.24042080988230605
# 0.37544095117265486
# original hmc
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-187-a4160871ac56> in <module>()
#      19 print(np.var(q_traj_sorted_sghmc[:,2]))
#      20 print('original hmc')
# ---> 21 print(np.var(q_traj_sorted[:,0]))
#      22 print(np.var(q_traj_sorted[:,1]))
#      23 print(np.var(q_traj_sorted[:,2]))
#
# NameError: name 'q_traj_sorted' is not defined

# %%
# Adding noise to full gradient with known covariance to test SGHMC method

def force(q,y):
    m1,m2,m3 = q
    
    n = len(y)
    p_prior = np.exp(-(13.5 - m1)**2/32)*np.exp(-(13.5 - m2)**2/32)*np.exp(-(13.5 - m3)**2/32)
    
    m1_vec = m1*np.ones(n)
    m2_vec = m2*np.ones(n)
    m3_vec = m3*np.ones(n)
    p_hat = np.exp(-(y-m1_vec)**2/2) + np.exp(-(y-m2_vec)**2/2) + np.exp(-(y-m3_vec)**2/2)
    
    # Take the negative of each gradient
    grad_m1 = -(-(1/16)*(13.5 - m1) + sum(-(y - m1_vec)*np.exp(-(y - m1_vec)**2/2)/p_hat))
    grad_m2 = -(-(1/16)*(13.5 - m2) + sum(-(y - m2_vec)*np.exp(-(y - m2_vec)**2/2)/p_hat))
    grad_m3 = -(-(1/16)*(13.5 - m3) + sum(-(y - m3_vec)*np.exp(-(y - m3_vec)**2/2)/p_hat))
    
    return np.asarray([grad_m1,grad_m2,grad_m3])
    

def SGHMC_known_cov(q0,h,y):
    # n is the size of the batch
    q = q0
    p = np.random.randn(3)
    current_p = p
    M = np.eye(3)   # preconditioning matrix set to identity. can be used to precondition sampler 
    # when we have more info about target distribution
    
    cov = np.array([[3,.1,.1],[.1,4,.1],[.1,.1,2]])
    grad_noise = cov.dot(np.random.randn(3))
    
    grad = force(q,y) - grad_noise
    # for now set C=B_hat and B=zeros(3)
    B = .5*h*cov
    #added_noise = np.random.multivariate_normal(np.zeros(3), 2*h*B, 1)
    
    p = p + h*grad + h*B.dot(p)
    q = q + h*p
    
    return q,p

# %%
def run_simulation_known_cov( q0,p0, Nsteps, h, step_function, Y):
    
    q_traj = [np.copy(q0)] 
    p_traj = [np.copy(p0)]
    t_traj = [0]

    q = np.copy(q0) 
    p = np.copy(p0)
    t = 0 

    for n in range(Nsteps):
        q,p = step_function(q, h, Y)
        t = t + h 

        q_traj += [q]  
        t_traj += [t] 

    q_traj = np.array(q_traj) 
    p_traj = np.array(p_traj) 
    t_traj = np.array(t_traj) 

    return q_traj, p_traj, t_traj

# %%
q0 = np.random.randn(3) + 13   # initialise q0 to be close to the mean (of tomato mass)
p0 = np.random.randn(3)


Nsteps = 100000
h = 0.2

# Run one long trajectory of Nsteps, using the ABO scheme
q_traj_known_cov, p_traj, t_traj = run_simulation_known_cov(q0, p0, Nsteps , h, SGHMC_known_cov, Y)

# %%
fig = plt.figure(figsize=[15,4])

plt.subplot(1,2,1)
plt.plot( t_traj, q_traj_known_cov )
plt.title('Trajectory of $q$')
plt.ylabel('$q(t)$')
plt.xlabel('Time $t$')

plt.subplot(1,2,2)
hist1,bins1 = np.histogram(q_traj_known_cov[:,0], bins=50,range=[9,18], density=True)
midx1 = (bins1[0:-1]+bins1[1:])/2
hist2,bins2 = np.histogram(q_traj_known_cov[:,1], bins=50,range=[9,18], density=True)
midx2 = (bins2[0:-1]+bins2[1:])/2
hist3,bins3 = np.histogram(q_traj_known_cov[:,2], bins=50,range=[9,18], density=True)
midx3 = (bins3[0:-1]+bins3[1:])/2
plt.plot(midx1,hist1,label='$\mu_A$')
plt.plot(midx2,hist2,label='$\mu_B$')
plt.plot(midx3,hist3,label='$\mu_C$')

plt.title('Histograms of distributions of $q = [\mu_A, \mu_B, \mu_C]$')
plt.xlabel('Mass (g)')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
n = q_traj.shape[0]  # get number of time steps
q_traj_sorted_cov = q_traj_known_cov.copy()


q_traj_sorted_cov = np.sort(q_traj_known_cov)
    
plt.hist(q_traj_sorted_cov[:,0], bins=15,label='$\mu_A$', alpha=0.7)
plt.hist(q_traj_sorted_cov[:,1], bins=15, label='$\mu_B$',alpha=0.7)
plt.hist(q_traj_sorted_cov[:,2], bins=15, label='$\mu_C$',alpha=0.7)
plt.title('Histograms of distributions of $q = [\mu_A, \mu_B, \mu_C]$ after sorted')
plt.xlabel('Mass (g)')
plt.ylabel('Frequency')
plt.legend()
plt.show()


# original hmc 


plt.hist(q_traj_sorted[:,0], bins=15,label='$\mu_A$', alpha=0.7)
plt.hist(q_traj_sorted[:,1], bins=15, label='$\mu_B$',alpha=0.7)
plt.hist(q_traj_sorted[:,2], bins=15, label='$\mu_C$',alpha=0.7)
plt.title('Histograms of distributions of $q = [\mu_A, \mu_B, \mu_C]$ after sorted')
plt.xlabel('Mass (g)')
plt.ylabel('Frequency')
plt.legend()
plt.show()

print(np.var(q_traj_sorted_cov[:,0]))
print(np.var(q_traj_sorted_cov[:,1]))
print(np.var(q_traj_sorted_cov[:,2]))
print('original hmc')
print(np.var(q_traj_sorted[:,0]))
print(np.var(q_traj_sorted[:,1]))
print(np.var(q_traj_sorted[:,2]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-186-fbf55c00125b> in <module>()
#      18
#      19
# ---> 20 plt.hist(q_traj_sorted[:,0], bins=15,label='$\mu_A$', alpha=0.7)
#      21 plt.hist(q_traj_sorted[:,1], bins=15, label='$\mu_B$',alpha=0.7)
#      22 plt.hist(q_traj_sorted[:,2], bins=15, label='$\mu_C$',alpha=0.7)
#
# NameError: name 'q_traj_sorted' is not defined

# %%
# generate more tomatoe-like data
N = 500
d1 = np.random.normal(11.2115,0.5486,int(N/3))
d2 = np.random.normal(13.5618,0.62927,int((N-int(N/3))/2))
d3 = np.random.normal(16.115,0.5714,N-2*int((N-int(N/3))/2))

BigY = np.random.choice(np.concatenate([d1,d2,d3]), N, replace=True)

# %%
np.min(BigY)
# Out:
# 10.179677293062458

# %%
Nsteps = 10000
h = 0.1

tic = time.clock()
# Run one long trajectory of Nsteps, using the ABO scheme
q_traj_sghmc, p_traj, t_traj = run_simulation_sghmc(q0, p0, Nsteps , h, SGHMC, BigY, 10)
toc = time.clock()
print(toc - tic)
# Out:
# Num scans 49.0
# B_hat: [[1170.85438526  179.02963868  219.34341508]
#  [ 179.02963868  390.09948728  555.4571063 ]
#  [ 219.34341508  555.4571063   816.62299897]]
# B_hat: [[145.17500806 -46.76710752   8.47519624]
#  [-46.76710752 408.26832653  47.96771729]
#  [  8.47519624  47.96771729  68.87716735]]
# B_hat: [[625.44714692 -50.66750945 -16.25568144]
#  [-50.66750945  94.16368548  56.658218  ]
#  [-16.25568144  56.658218   484.5715719 ]]
# B_hat: [[ 106.17853655   13.83661064   14.41979738]
#  [  13.83661064  352.01256983 -147.62015336]
#  [  14.41979738 -147.62015336  150.19808438]]
# B_hat: [[ 946.93502193 -117.83888889  -48.13416112]
#  [-117.83888889  124.77660675    2.67767017]

# masses: -23.151390367346064 -30.301246103631243 -31.224685029872568
# [4.35385138e-265 0.00000000e+000 2.94827292e-266 8.44209693e-296
#  9.17141215e-262 0.00000000e+000 0.00000000e+000 2.66795449e-321
#  0.00000000e+000 1.07109541e-287]
# masses: -23.151390367346064 -30.301246103631243 -31.224685029872568
# [4.35385138e-265]
# masses: -23.151390367346064 -30.301246103631243 -31.224685029872568
# [0.]
# masses: -23.151390367346064 -30.301246103631243 -31.224685029872568
# [2.94827292e-266]
# masses: -23.151390367346064 -30.301246103631243 -31.224685029872568
# [8.44209693e-296]
# masses: -23.151390367346064 -30.301246103631243 -31.224685029872568
# [9.17141215e-262]
# masses: -23.151390367346064 -30.301246103631243 -31.224685029872568
# [0.]
# masses: -23.151390367346064 -30.301246103631243 -31.224685029872568
# [0.]
# masses: -23.151390367346064 -30.301246103631243 -31.224685029872568
# [2.67e-321]
# masses: -23.151390367346064 -30.301246103631243 -31.224685029872568
# [0.]
# masses: -23.151390367346064 -30.301246103631243 -31.224685029872568
# [1.07109541e-287]
# masses: -23.151390367346064 -30.301246103631243 -31.224685029872568
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:25: RuntimeWarning: invalid value encountered in true_divide
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:26: RuntimeWarning: invalid value encountered in true_divide
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:27: RuntimeWarning: invalid value encountered in true_divide
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in less
# 21.298933000000034

# %%
fig = plt.figure(figsize=[15,10])

plt.hist(q_traj_sghmc[:,0], bins=15,label='$\mu_A$', alpha=0.5)
plt.hist(q_traj_sghmc[:,1], bins=15, label='$\mu_B$',alpha=0.5)
plt.hist(q_traj_sghmc[:,2], bins=15, label='$\mu_C$',alpha=0.5)
plt.title('Histograms of distributions of $q = [\mu_A, \mu_B, \mu_C]$')
plt.xlabel('Mass (g)')
plt.ylabel('Frequency')
plt.legend()

fig = plt.figure()

hist1,bins1 = np.histogram(q_traj_sghmc[:,0], bins=50,range=[9,18], density=True)
midx1 = (bins1[0:-1]+bins1[1:])/2
hist2,bins2 = np.histogram(q_traj_sghmc[:,1], bins=50,range=[9,18], density=True)
midx2 = (bins2[0:-1]+bins2[1:])/2
hist3,bins3 = np.histogram(q_traj_sghmc[:,2], bins=50,range=[9,18], density=True)
midx3 = (bins3[0:-1]+bins3[1:])/2
plt.plot(midx1,hist1,label='$\mu_A$')
plt.plot(midx2,hist2,label='$\mu_B$')
plt.plot(midx3,hist3,label='$\mu_C$')

plt.title('Histograms of distributions of $q = [\mu_A, \mu_B, \mu_C]$')
plt.xlabel('Mass (g)')
plt.ylabel('Frequency')
plt.legend()
plt.show()
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:780: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:781: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
plt.plot( t_traj, q_traj_sghmc )
plt.title('Trajectory of $q$')
plt.ylabel('$q(t)$')
plt.xlabel('Time $t$')
plt.show()

# %%
# Run big data with known covariance


q0 = np.random.randn(3) + 13   # initialise q0 to be close to the mean (of tomato mass)
p0 = np.random.randn(3)


Nsteps = 100000
h = 0.1

# Run one long trajectory of Nsteps, using the ABO scheme
q_traj_known_cov, p_traj, t_traj = run_simulation_known_cov(q0, p0, Nsteps , h, SGHMC_known_cov, BigY)

# %%
# plot with known covariance




fig = plt.figure(figsize=[15,4])

plt.subplot(1,2,1)
plt.plot( t_traj, q_traj_known_cov )
plt.title('Trajectory of $q$')
plt.ylabel('$q(t)$')
plt.xlabel('Time $t$')

plt.subplot(1,2,2)
hist1,bins1 = np.histogram(q_traj_known_cov[:,0], bins=50,range=[9,18], density=True)
midx1 = (bins1[0:-1]+bins1[1:])/2
hist2,bins2 = np.histogram(q_traj_known_cov[:,1], bins=50,range=[9,18], density=True)
midx2 = (bins2[0:-1]+bins2[1:])/2
hist3,bins3 = np.histogram(q_traj_known_cov[:,2], bins=50,range=[9,18], density=True)
midx3 = (bins3[0:-1]+bins3[1:])/2
plt.plot(midx1,hist1,label='$\mu_A$')
plt.plot(midx2,hist2,label='$\mu_B$')
plt.plot(midx3,hist3,label='$\mu_C$')

plt.title('Histograms of distributions of $q = [\mu_A, \mu_B, \mu_C]$')
plt.xlabel('Mass (g)')
plt.ylabel('Frequency')
plt.legend()
plt.show()
